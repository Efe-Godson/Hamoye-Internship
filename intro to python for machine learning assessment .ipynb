# %%
import pandas as pd
import numpy as np

# %%
food = pd.read_csv(r"C:\Users\Efe Godson\Downloads\FoodBalanceSheets_E_Africa_NOFLAG.csv", encoding= "latin-1")

# %%
food.head(5)
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
food.groupby("Element")[["Y2014","Y2015","Y2016","Y2017","Y2018"]].sum()
# Out:
#                                              Y2014       Y2015       Y2016  \
# Element
# Domestic supply quantity                1996716.35  2021493.55  2044842.70
# Export Quantity                          150020.64   157614.47   151920.46
# Fat supply quantity (g/capita/day)        10225.56    10235.74    10102.77
# Feed                                     216927.89   225050.22   228958.65
# Food                                    1212332.49  1232361.10  1247022.17
# Food supply (kcal/capita/day)            454257.00   453383.00   451810.00
# Food supply quantity (kg/capita/yr)       49650.63    49345.13    48985.28
# Import Quantity                          274144.48   267018.46   286582.78
# Losses                                   153223.00   155439.00   157787.00
# Other uses (non-food)                     78718.13    66254.41    69563.68
# Processing                               282923.00   287929.00   280631.00
# ...

# %%
food.groupby("Area")[["Element" = 'Protein supply quantity (g/capita/day)'' ,"Y2017"]].sum()
# Out:
#   File "C:\Users\EFEGOD~1\AppData\Local\Temp/ipykernel_2692/419902073.py", line 1
#     food.groupby("Area")[["Element" = 'Protein supply quantity (g/capita/day)'' ,"Y2017"]].sum()
#                                     ^
# SyntaxError: invalid syntax

# %%
mad = food[food["Element"] == 'Protein supply quantity (g/capita/day)']
# Out:
#        Area Code      Area  Item Code                      Item  Element Code  \
# 3              4   Algeria       2901               Grand Total           674
# 6              4   Algeria       2903          Vegetal Products           674
# 9              4   Algeria       2941           Animal Products           674
# 25             4   Algeria       2905  Cereals - Excluding Beer           674
# 41             4   Algeria       2511        Wheat and products           674
# ...          ...       ...        ...                       ...           ...
# 60903        181  Zimbabwe       2769   Aquatic Animals, Others           674
# 60911        181  Zimbabwe       2775            Aquatic Plants           674
# 60921        181  Zimbabwe       2928             Miscellaneous           674
# 60931        181  Zimbabwe       2680               Infant food           674
# 60941        181  Zimbabwe       2899             Miscellaneous           674
#
# ...

# %%
mad.groupby('Area').sum()
# Out:
#                              Area Code  Item Code  Element Code   Y2014  \
# Area
# Algeria                            432     291489         72792  379.56
# Angola                             791     304356         76162  231.66
# Benin                             5777     293767         73466  275.28
# Botswana                          2260     304560         76162  275.18
# Burkina Faso                     26329     304269         76162  321.31
# Cabo Verde                        3640     280998         70096  276.71
# Cameroon                          3680     309693         77510  287.66
# Central African Republic          4181     304086         76162  175.05
# Chad                              4290     296797         74140  254.70
# Congo                             5198     304663         76162  207.55
# Côte d'Ivoire                    12412     312274         78184  221.81
# Djibouti                          7272     273345         68074  256.89
# ...

# %%
area=food[["Area","Y2017"]]
area
# Out:
#            Area     Y2017
# 0       Algeria  41389.00
# 1       Algeria      0.00
# 2       Algeria   3341.00
# 3       Algeria     92.82
# 4       Algeria     80.19
# ...         ...       ...
# 60938  Zimbabwe     19.00
# 60939  Zimbabwe      1.33
# 60940  Zimbabwe      1.00
# 60941  Zimbabwe      0.04
# 60942  Zimbabwe      0.02
#
# [60943 rows x 2 columns]

# %%
area.groupby('Area').sum()
# Out:
#                                   Y2017
# Area
# Algeria                       325644.27
# Angola                        229159.57
# Benin                         124771.22
# Botswana                       22101.30
# Burkina Faso                  101855.07
# Cabo Verde                     14650.74
# Cameroon                      232030.43
# Central African Republic       29937.00
# Chad                           71594.68
# Comoros                           59.84
# Congo                          41181.68
# Côte d'Ivoire                 224599.01
# Djibouti                       22729.91
# Egypt                         866379.92
# Eswatini                       54343.33
# Ethiopia                      448683.76
# Ethiopia PDR                       0.00
# Gabon                          27979.64
# Gambia                         23154.18
# Ghana                         337599.06
# Guinea                         98138.87
# Guinea-Bissau                  19102.77
# ...

# %%
food.groupby("Item").sum()
# Out:
#                      Area Code  Item Code  Element Code      Y2014      Y2015  \
# Item
# Alcohol, Non-Food        38447     752497       1515090    2403.00    2180.00
# Alcoholic Beverages      75016    1649136       2171381  102410.11   98783.72
# Animal Products          18060     397035         90990   11935.65   11811.73
# Animal fats              85279    1882494       2567303  209460.54  200675.72
# Apples and products      69280    1352989       1920418    9499.23   10559.15
# ...                        ...        ...           ...        ...        ...
# Vegetables, Other        77779    1518715       2275409  155038.96  158104.08
# Vegetal Products         18060     391905         90990  107145.19  107064.17
# Wheat and products       87073    1639683       2654934  232670.13  234710.51
# Wine                     66206    1319535       1818328    4497.36    4251.81
# Yams                     50798     970905       1525745  200396.96  203151.78
#
# ...

# %%
food.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
food.mean()
# Out:
# C:\Users\EFEGOD~1\AppData\Local\Temp/ipykernel_2692/2058069428.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   food.mean()
# Area Code        134.265576
# Item Code       2687.176706
# Element Code    3814.856456
# Y2014            134.196282
# Y2015            135.235966
# Y2016            136.555222
# Y2017            140.917765
# Y2018            143.758381
# dtype: float64

# %%
food.std()
# Out:
# C:\Users\EFEGOD~1\AppData\Local\Temp/ipykernel_2692/1561304323.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   food.std()
# Area Code         72.605709
# Item Code        146.055739
# Element Code    2212.007033
# Y2014           1567.663696
# Y2015           1603.403984
# Y2016           1640.007194
# Y2017           1671.862359
# Y2018           1710.782658
# dtype: float64

# %%
food['Area'].unique().size
# Out:
# 49

# %%
food[['Element'].corr()
# Out:
#   File "C:\Users\EFEGOD~1\AppData\Local\Temp/ipykernel_2692/2584227473.py", line 1
#     food[['Element'].corr()
#                            ^
# SyntaxError: unexpected EOF while parsing

# %%
my_tuppy = (1,2,5,8)

my_tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\EFEGOD~1\AppData\Local\Temp/ipykernel_2692/3917941094.py in <module>
#       1 my_tuppy = (1,2,5,8)
#       2
# ----> 3 my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %%
area.sort_values('Y2017',ascending= True).head(7)
# Out:
#                               Area   Y2017
# 16481                        Egypt -1582.0
# 16512                        Egypt -1582.0
# 39032                   Mozambique -1200.0
# 39016                   Mozambique -1159.0
# 57092  United Republic of Tanzania  -865.0
# 57120  United Republic of Tanzania  -860.0
# 51338                        Sudan  -819.0
